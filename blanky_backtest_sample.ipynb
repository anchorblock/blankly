# %%
import requests
import blankly
from blankly.data import PriceReader
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### their ideal backtest

# %%
def price_event(price, symbol, state: blankly.StrategyState):
    """ This function will give an updated price every 15 seconds from our definition below """
    state.variables['history'].append(price)
    rsi = blankly.indicators.rsi(state.variables['history'])
    curr_value = state.interface.account[state.base_asset].available
    if rsi[-1] < 30 and not curr_value:
        # Dollar cost average buy
        buy = blankly.trunc(state.interface.cash / price, 5)
        state.interface.market_order(symbol, side='buy', size=buy)
    elif rsi[-1] > 70 and curr_value:
        # Dollar cost average sell
        state.interface.market_order(symbol, side='sell', size=curr_value)


def init(symbol, state: blankly.StrategyState):
    # Download price data to give context to the algo
    state.variables['history'] = state.interface.history(symbol, to=150, return_as='deque',
                                                         resolution=state.resolution)['close']

# %%
if __name__ == "__main__":
    # This downloads an example CSV
    data = requests.get(
        'https://firebasestorage.googleapis.com/v0/b/blankly-6ada5.appspot.com/o/demo_data.csv?alt=media&token=acfa5c39-8f08-45dc-8be3-2033dc2b7b28').text
    with open('./price_examples.csv', 'w') as file:
        file.write(data)

    # Run on the keyless exchange, starting at 100k
    exchange = blankly.KeylessExchange(price_reader=PriceReader('./price_examples.csv', 'BTC-USD'))

    # Use our strategy helper
    strategy = blankly.Strategy(exchange)

    # Make the price event function above run every day
    strategy.add_price_event(price_event, symbol='BTC-USD', resolution='1d', init=init)

    # Backtest the strategy
    results = strategy.backtest(start_date=1598377600, end_date=1650067200, initial_values={'USD': 10000})
    print(results)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Documents/blankly/blankly/utils/utils.py:188, in __BlanklySettings.load(self, override_path, override_allow_nonexistent)
#     187 try:
# --> 188     preferences = load_json_file(self.__default_path)
#     189 except FileNotFoundError:
#
# File ~/Documents/blankly/blankly/utils/utils.py:135, in load_json_file(override_path)
#     134 def load_json_file(override_path=None):
# --> 135     f = open(override_path, )
#     136     json_file = json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: './settings.json'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 9
#       6     file.write(data)
#       8 # Run on the keyless exchange, starting at 100k
# ----> 9 exchange = blankly.KeylessExchange(price_reader=PriceReader('./price_examples.csv', 'BTC-USD'))
#      11 # Use our strategy helper
#      12 strategy = blankly.Strategy(exchange)
#
# File ~/Documents/blankly/blankly/exchanges/interfaces/keyless/keyless.py:30, in KeylessExchange.__init__(self, maker_fee, taker_fee, portfolio_name, settings_path, price_reader, initial_account_values)
#      28 def __init__(self, maker_fee=0, taker_fee=0, portfolio_name=None, settings_path=None,
#      29              price_reader: [PriceReader, list] = None, initial_account_values: dict = None):
# ---> 30     Exchange.__init__(self, "keyless", portfolio_name, settings_path)
#      32     self.calls = KeylessAPI(maker_fee, taker_fee, price_reader)
#      34     self.interface = PaperTradeInterface(self.calls, initial_account_values)
#
# File ~/Documents/blankly/blankly/exchanges/exchange.py:44, in Exchange.__init__(self, exchange_type, portfolio_name, preferences_path)
#      41 # Make a public version of portfolio name
#      42 self.portfolio_name = self.__name
# ---> 44 self.preferences = blankly.utils.load_user_preferences(preferences_path)
#      46 self.models = {}
#      48 # Fill this in the method below
#
# File ~/Documents/blankly/blankly/utils/utils.py:233, in load_user_preferences(override_path, override_allow_nonexistent)
#     232 def load_user_preferences(override_path=None, override_allow_nonexistent=False) -> dict:
# --> 233     return general_settings.load(override_path, override_allow_nonexistent=override_allow_nonexistent)
#
# File ~/Documents/blankly/blankly/utils/utils.py:196, in __BlanklySettings.load(self, override_path, override_allow_nonexistent)
#     191         return self.__default_settings
#     192         # self.write(self.__default_settings)
#     193         # # Recursively run this
#     194         # return self.load(override_path)
#     195     else:
# --> 196         raise FileNotFoundError(self.__not_found_err)
#     197 preferences = self.__compare_dicts(self.__default_settings, preferences)
#     198 self.__settings_cache[self.__default_path] = preferences
#
# FileNotFoundError: Make sure a settings.json file is placed in the same folder as the project working directory!

# %%
type(results)
# Out:
# blankly.exchanges.interfaces.paper_trade.backtest_result.BacktestResult

# %% [markdown]
# ### data processing

# %%
aapl=pd.read_csv('../price-data/AAPL.csv',index_col=0)

# %%
aapl
# Out:
#                   open        high         low       close     volume
# date
# 2018-01-02   42.540001   43.075001   42.314999   43.064999  102223600
# 2018-01-03   43.132500   43.637501   42.990002   43.057499  118071600
# 2018-01-04   43.134998   43.367500   43.020000   43.257500   89738400
# 2018-01-05   43.360001   43.842499   43.262501   43.750000   94640000
# 2018-01-08   43.587502   43.902500   43.482498   43.587502   82271200
# ...                ...         ...         ...         ...        ...
# 2023-06-23  185.550003  187.559998  185.009995  186.679993   53079300
# 2023-06-26  186.830002  188.050003  185.229996  185.270004   48088700
# 2023-06-27  185.889999  188.389999  185.669998  188.059998   50730800
# 2023-06-28  187.929993  189.899994  187.600006  189.250000   51216800
# 2023-06-29  189.080002  190.070007  188.940002  189.589996   46347300
#
# [1382 rows x 5 columns]

# %% [markdown]
# I need to convert the date at epoch and make it a column named time

# %%
aapl.index=pd.to_datetime(aapl.index)
aapl['time'] = aapl.index.astype(int) // 10**9

# Reset the index to remove the datetime index
aapl.reset_index(drop=True, inplace=True)

# Move the 'time' column to the first position
cols = list(aapl.columns)
cols = [cols[-1]] + cols[:-1]
aapl = aapl[cols]

# %%
aapl
# Out:
#             time        open        high         low       close     volume
# 0     1514851200   42.540001   43.075001   42.314999   43.064999  102223600
# 1     1514937600   43.132500   43.637501   42.990002   43.057499  118071600
# 2     1515024000   43.134998   43.367500   43.020000   43.257500   89738400
# 3     1515110400   43.360001   43.842499   43.262501   43.750000   94640000
# 4     1515369600   43.587502   43.902500   43.482498   43.587502   82271200
# ...          ...         ...         ...         ...         ...        ...
# 1377  1687478400  185.550003  187.559998  185.009995  186.679993   53079300
# 1378  1687737600  186.830002  188.050003  185.229996  185.270004   48088700
# 1379  1687824000  185.889999  188.389999  185.669998  188.059998   50730800
# 1380  1687910400  187.929993  189.899994  187.600006  189.250000   51216800
# 1381  1687996800  189.080002  190.070007  188.940002  189.589996   46347300
#
# [1382 rows x 6 columns]

# %%
aapl.to_csv('../price-data/AAPL-USD.csv',index=False)

# %%
def price_event(price, symbol, state: blankly.StrategyState):
    """ This function will give an updated price every 15 seconds from our definition below """
    state.variables['history'].append(price)
    sma = blankly.indicators.sma(state.variables['history'])
    curr_value = state.interface.account[state.base_asset].available
    if price > sma[-1] and not curr_value:
        # Dollar cost average buy
        buy = blankly.trunc(state.interface.cash / price, 5)
        state.interface.market_order(symbol, side='buy', size=buy)
    elif price < sma[-1] and curr_value:
        # Dollar cost average sell
        state.interface.market_order(symbol, side='sell', size=curr_value)


def init(symbol, state: blankly.StrategyState):
    # Download price data to give context to the algo
    state.variables['history'] = state.interface.history(symbol, to=100, return_as='deque',
                                                         resolution=state.resolution)['close']

# %%
if __name__ == "__main__":
    

    # Run on the keyless exchange, starting at 100k
    exchange = blankly.KeylessExchange(price_reader=PriceReader('/home/mehedi/Documents/blankly/price-data/AAPL-USD.csv', 'AAPL-USD'))

    # Use our strategy helper
    strategy = blankly.Strategy(exchange)

    # Make the price event function above run every day
    strategy.add_price_event(price_event, symbol='AAPL-USD', resolution='1d', init=init)

    # Backtest the strategy
    results = strategy.backtest(start_date=1527120000, end_date=1687910400, initial_values={'USD': 1000000})
    print(results)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/blankly/lib/python3.10/site-packages/blankly/utils/utils.py:188, in __BlanklySettings.load(self, override_path, override_allow_nonexistent)
#     187 try:
# --> 188     preferences = load_json_file(self.__default_path)
#     189 except FileNotFoundError:
#
# File ~/anaconda3/envs/blankly/lib/python3.10/site-packages/blankly/utils/utils.py:135, in load_json_file(override_path)
#     134 def load_json_file(override_path=None):
# --> 135     f = open(override_path, )
#     136     json_file = json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: './settings.json'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 5
#       1 if __name__ == "__main__":
#       2
#       3
#       4     # Run on the keyless exchange, starting at 100k
# ----> 5     exchange = blankly.KeylessExchange(price_reader=PriceReader('/home/mehedi/Documents/blankly/price-data/AAPL-USD.csv', 'AAPL-USD'))
#       7     # Use our strategy helper
#       8     strategy = blankly.Strategy(exchange)
#
# File ~/anaconda3/envs/blankly/lib/python3.10/site-packages/blankly/exchanges/interfaces/keyless/keyless.py:30, in KeylessExchange.__init__(self, maker_fee, taker_fee, portfolio_name, settings_path, price_reader, initial_account_values)
#      28 def __init__(self, maker_fee=0, taker_fee=0, portfolio_name=None, settings_path=None,
#      29              price_reader: [PriceReader, list] = None, initial_account_values: dict = None):
# ---> 30     Exchange.__init__(self, "keyless", portfolio_name, settings_path)
#      32     self.calls = KeylessAPI(maker_fee, taker_fee, price_reader)
#      34     self.interface = PaperTradeInterface(self.calls, initial_account_values)
#
# File ~/anaconda3/envs/blankly/lib/python3.10/site-packages/blankly/exchanges/exchange.py:44, in Exchange.__init__(self, exchange_type, portfolio_name, preferences_path)
#      41 # Make a public version of portfolio name
#      42 self.portfolio_name = self.__name
# ---> 44 self.preferences = blankly.utils.load_user_preferences(preferences_path)
#      46 self.models = {}
#      48 # Fill this in the method below
#
# File ~/anaconda3/envs/blankly/lib/python3.10/site-packages/blankly/utils/utils.py:233, in load_user_preferences(override_path, override_allow_nonexistent)
#     232 def load_user_preferences(override_path=None, override_allow_nonexistent=False) -> dict:
# --> 233     return general_settings.load(override_path, override_allow_nonexistent=override_allow_nonexistent)
#
# File ~/anaconda3/envs/blankly/lib/python3.10/site-packages/blankly/utils/utils.py:196, in __BlanklySettings.load(self, override_path, override_allow_nonexistent)
#     191         return self.__default_settings
#     192         # self.write(self.__default_settings)
#     193         # # Recursively run this
#     194         # return self.load(override_path)
#     195     else:
# --> 196         raise FileNotFoundError(self.__not_found_err)
#     197 preferences = self.__compare_dicts(self.__default_settings, preferences)
#     198 self.__settings_cache[self.__default_path] = preferences
#
# FileNotFoundError: Make sure a settings.json file is placed in the same folder as the project working directory!
